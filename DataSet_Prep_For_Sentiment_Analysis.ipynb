# %%
"""
Příprava funkce pro zeštíhlení datasetu. Příprava sloupců ratings, average ratings_avg a reviews, 
kdy skupina reviews a skupina ratingu náleží jednomu produktu.
"""

import pandas as pd
import numpy as np

def clean_df(df):
    df_summary = pd.concat([df.filter(like = 'cons') , df.filter(like ='pros') , df.filter(like='summary')], axis=1)
    df_summary = df_summary.fillna('')
    df_summary['reviews'] = df_summary.apply(lambda row: "\n".join(filter(None, row.values.astype(str))), axis=1) #.replace('\n+','\n')
    df_rating = df.filter(like = 'rating')
    df_rating['ratings'] = df_rating.values.tolist()
    df_rating['ratings_avg'] = df_rating['ratings'].apply(np.nanmean)
    return pd.concat([df.iloc[:,0:3], df_rating['ratings'], df_rating['ratings_avg'], df_summary['reviews']], axis=1)

# %%
"""
Aplikace funkce na jednotlivé datasety.
"""

df_tampony = pd.read_csv('./data/Heureka_Tampony.csv')
df_tampony = clean_df(df_tampony)
df_tampony.head(100)
# Out:
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings'] = df_rating.values.tolist()
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: RuntimeWarning: Mean of empty slice
#   return lib.map_infer(values, mapper, convert=convert)
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings_avg'] = df_rating['ratings'].apply(np.nanmean)
#    TYP_HEUREKA                                   itemName_HEUREKA  \
# 0      tampony             O.B. ProComfort Triopack tampony 24 ks
# 1      tampony                  o.b. Original tampony Super 32 ks
# 2      tampony  Tampax Cotton Protection Regular Tampony S Apl...
# 3      tampony      Elkos Tampony Mini s hedvábným povrchem 64 ks
# 4      tampony                Beppy tampony Soft Comfort Wet 8 ks
# ..         ...                                                ...
# 95     tampony              O.B. Tampóny ExtraProtect Super 16 ks
# 96     tampony                        o.b. ProComfort Super 16 ks
# 97     tampony                        o.b. ProComfort Super 32 ks
# 98     tampony              Joydivision Soft Tampons normal 50 ks
# 99     tampony                                  Kotex Super 16 ks
#
#                                       itemUrl_HEUREKA  \
# 0   https://hygienicke-tampony.heureka.cz/o-b-proc...
# 1   https://hygienicke-tampony.heureka.cz/o-b-orig...
# 2   https://hygienicke-tampony.heureka.cz/tampax-c...
# 3   https://hygienicke-tampony.heureka.cz/elkos-ta...
# 4   https://hygienicke-tampony.heureka.cz/beppy-ta...
# ..                                                ...
# 95  https://hygienicke-tampony.heureka.cz/o-b-tamp...
# 96  https://hygienicke-tampony.heureka.cz/o-b-proc...
# 97  https://hygienicke-tampony.heureka.cz/o-b-proc...
# 98  https://hygienicke-tampony.heureka.cz/joydivis...
# 99  https://hygienicke-tampony.heureka.cz/kotex-su...
#
#                                               ratings  ratings_avg  \
# 0   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# 1   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# 2   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# 3   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# 4   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# ..                                                ...          ...
# 95  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...          NaN
# 96  [9.0, 10.0, 10.0, 1.0, 5.0, 10.0, nan, nan, na...     7.500000
# 97  [10.0, 10.0, 10.0, 10.0, nan, nan, nan, nan, n...    10.000000
# 98  [10.0, 10.0, 10.0, 8.0, 10.0, 9.0, 10.0, nan, ...     9.571429
# 99  [9.0, 10.0, 10.0, 10.0, 10.0, 10.0, 6.0, 10.0,...     8.888889
#
#                                               reviews
# 0
# 1
# 2
# 3
# 4
# ..                                                ...
#
1116,1117,1119,1120,1123,1126,1128,1129,1130,1131,1133,1135,1137,1141,1142,1143,1144,1146,1147,1148,1150,1151,1152,1153,1154,1155,1157,1158,1161,1162,1164,1165,1166,1167,1168,1169,1170,1172,1175,1176,1177,1178,1179,1180,1183,1187,1188,1189,1190,1191,1194,1196,1197,1198,1199,1200,1201,1202,1204,1205,1206,1208,1209,1211,1214,1215,1217,1218,1221,1224,1226,1227,1228,1230,1231,1233,1236,1237,1238,1239,1240,1242,1245,1246,1247,1249,1250,1253,1255,1256,1258,1259,1263,1265,1266,1267,1268,1270,1271,1273,1275,1277,1278,1279,1280,1282,1285,1287,1288,1289,1290,1292,1294,1295,1298,1299,1300,1301,1302,1303,1304,1306,1308,1311,1312,1313,1314,1315,1317,1321,1322,1323,1324,1325,1327,1328,1331,1333,1334,1336,1337,1339,1341,1345,1346,1347,1348,1353,1354,1355,1357,1358,1359,1360,1362,1364,1366,1367,1368,1369,1371,1373,1377,1379,1380,1382,1383,1385,1387,1389,1390,1391,1392,1394,1395,1397,1399,1403,1404,1405,1407,1408,1411,1413,1415,1416,1417,1418,1419,1421,1424,1426,1427,1428,1429,1430,1431,1434,1436,1438,1439,1441,1443,1444,1446,1447,1449,1451,1452,1453,1456,1457,1458,1459,1461,1463,1464,1466,1467,1468,1470,1471,1473,1474,1476,1478,1479,1480,1482,1486,1488,1492,1493,1494,1496,1497,1500,1503,1504,1505,1506,1507,1508,1510,1513,1514,1515,1517,1519,1521,1522,1523,1524,1525,1527,1528,1529,1530,1531,1533,1535,1537,1538,1539,154 ...
#   df_vlozky = pd.read_csv('./data/Heureka_Vlozky.csv')
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings'] = df_rating.values.tolist()
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: RuntimeWarning: Mean of empty slice
#   return lib.map_infer(values, mapper, convert=convert)
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings_avg'] = df_rating['ratings'].apply(np.nanmean)

# %%
df_kalisek = pd.read_csv('./data/Heureka_Kalisek.csv')
df_kalisek = clean_df(df_kalisek)
# Out:
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings'] = df_rating.values.tolist()
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: RuntimeWarning: Mean of empty slice
#   return lib.map_infer(values, mapper, convert=convert)
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings_avg'] = df_rating['ratings'].apply(np.nanmean)

# %%
df_kalhotky = pd.read_csv('./data/Heureka_Kalhotky.csv')
df_kalhotky = clean_df(df_kalhotky)
# Out:
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings'] = df_rating.values.tolist()
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: RuntimeWarning: Mean of empty slice
#   return lib.map_infer(values, mapper, convert=convert)
# /var/folders/hy/x226flw16n1fkrjz6cwf3lrw00014k/T/ipykernel_46289/3167335857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['ratings_avg'] = df_rating['ratings'].apply(np.nanmean)

# %%
"""
Spojení datasetů pod sebe a příprava nového DataFrame result. 
"""
frames = [df_kalhotky, df_kalisek, df_tampony, df_vlozky]

result = pd.concat(frames)
result.tail()
# Out:
#     TYP_HEUREKA                                   itemName_HEUREKA  \
# 811      vložky                tianDe Jemná péče denní vložky 1 ks
# 812      vložky  tianDe denní menštruační vložky Energie bylin ...
# 813      vložky  tianDe denní menštruační vložky Energie bylin ...
# 814      vložky  tianDe Nefritová svěžest denní vložky s aloe 2...
# 815      vložky            tianDe Energie života denní vložky 1 ks
#
#                                        itemUrl_HEUREKA  \
# 811  https://hygienicke-vlozky.heureka.cz/tiande-je...
# 812  https://hygienicke-vlozky.heureka.cz/tiande-de...
# 813  https://hygienicke-vlozky.heureka.cz/tiande-de...
# 814  https://hygienicke-vlozky.heureka.cz/tiande-ne...
# 815  https://hygienicke-vlozky.heureka.cz/tiande-en...
#
#                                                ratings  ratings_avg  \
# 811  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     9.936364
# 812  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 9.0...     9.754545
# 813  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     9.900000
# 814  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     9.909091
# 815  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     9.809091
#
#                                                reviews
# 811  -\nČISTOTA\nJsem spokojená\nJsou luxusni\nNa z...
# 812  -\nI\nÚčinné a příjemná vůně\nNaprostá spokoje...
# 813  Jsou velmi příjemné a hlavně s bylinky :-)\nBy...
# 814  -\nPro někoho mohou být svěží až moc\nJsou per...
# 815  Používáme při nachlazení,jako zábal na krk a s...

# %%
"""
Vypsání data setu do CSV.
"""
result.to_csv('Union_reviews.csv', index=False)

# %%
result.shape
# Out:
# (1405, 6)

# %%
#df_summary.dropna(how='all')
# Out:
#     TYP_HEUREKA                                   itemName_HEUREKA  \
# 0       tampony             O.B. ProComfort Triopack tampony 24 ks
# 1       tampony                  o.b. Original tampony Super 32 ks
# 2       tampony  Tampax Cotton Protection Regular Tampony S Apl...
# 3       tampony      Elkos Tampony Mini s hedvábným povrchem 64 ks
# 4       tampony                Beppy tampony Soft Comfort Wet 8 ks
# ..          ...                                                ...
# 166     tampony                      Gynotex Dry Soft-Tampons 1 ks
# 167     tampony                                 Senta Protect 4 ks
# 168     tampony         Ellen Probiotické tampony ECO Normal 22 ks
# 169     tampony                  Tampax Compak Economy Super 16 ks
# 170     tampony                                 Kotex Normal 32 ks
#
#                                        itemUrl_HEUREKA  \
# 0    https://hygienicke-tampony.heureka.cz/o-b-proc...
# 1    https://hygienicke-tampony.heureka.cz/o-b-orig...
# 2    https://hygienicke-tampony.heureka.cz/tampax-c...
# 3    https://hygienicke-tampony.heureka.cz/elkos-ta...
# 4    https://hygienicke-tampony.heureka.cz/beppy-ta...
# ..                                                 ...
# 166  https://hygienicke-tampony.heureka.cz/gynotex-...
# 167  https://hygienicke-tampony.heureka.cz/senta-pr...
# 168  https://hygienicke-tampony.heureka.cz/ellen-pr...
# 169  https://hygienicke-tampony.heureka.cz/tampax-c...
# 170  https://hygienicke-tampony.heureka.cz/kotex-no...
#
#                                               combined
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 166
# 167  Cena\ncena\nbalení - špatně se rozbaluje\ncena...
# 168  Tampon samotný nepatří mezi nejkvalitnější, př...
# 169  Velikost\nNic\nNejsou všude k sehnání.\nSuper ...
# 170  Nic\nnic\n-\ncena\nžádné\nnic\nnic\nPevnost\nP...
#
# [171 rows x 4 columns]

# %%
#df_summary.replace('', float('Nan'), inplace=True)
#df_summary.dropna(how='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/veronika.svecova/sentiment/data_set_prep_for_sentiment_analysis.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/veronika.svecova/sentiment/data_set_prep_for_sentiment_analysis.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df_summary.replace('', float('Nan'), inplace=True)
#       <a href='vscode-notebook-cell:/Users/veronika.svecova/sentiment/data_set_prep_for_sentiment_analysis.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> df_summary.dropna(how='all')
#
# NameError: name 'df_summary' is not defined
